# %%
from photozpy import StandardStarCatalog

# %%
standard_star = StandardStarCatalog(
    catalog_path="SDSS_DECam.h5",
)

# %%
standard_star.print_metadata()
# Out:
# ╒═════════════════╤════════════════════════════════════════════════════╕
# │ Field           │ Value                                              │
# ╞═════════════════╪════════════════════════════════════════════════════╡
# │ catalog_path    │ SDSS_DECam.h5                                      │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ table_node_path │ /sdss/decam/std                                    │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ table_node_name │ std                                                │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ table_title     │ Standard Stars                                     │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ table_columns   │ id_name, ra, ra_err, dec                           │
# │                 │ dec_err, SDSS_up, SDSS_gp, SDSS_rp                 │
# │                 │ SDSS_ip, SDSS_zp, UKIDSS_LAS_Y, SDSS_up_err        │
# │                 │ SDSS_gp_err, SDSS_rp_err, SDSS_ip_err, SDSS_zp_err │
# │                 │ UKIDSS_LAS_Y_err, ipix, bucket                     │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ bucket_size     │ 1536                                               │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ ra_unit         │ deg                                                │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ dec_unit        │ deg                                                │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ mag_system      │ {'SDSS_ugriz': 'AB', 'UKIDSS_LAS_Y': 'AB'}         │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ nside           │ 512                                                │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ order           │ nested                                             │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ source          │ https://www-star.fnal.gov/DECamStds/               │
# ├─────────────────┼────────────────────────────────────────────────────┤
# │ version         │ v1.0                                               │
# ╘═════════════════╧════════════════════════════════════════════════════╛

# %%
mag_cols = [
    "SDSS_up",
    "SDSS_gp",
    "SDSS_rp",
    "SDSS_ip",
    "SDSS_zp",
    "UKIDSS_LAS_Y",
]

standard_star_table = standard_star.find_standard_stars(
    fits_path="Master_SDSS J083701.85-011324.4_SDSS_g'.fits",
    edge_margin_pix=100,
    mag_limit=19,
    mag_columns=mag_cols,
)

# %%
standard_star_table
# Out:
#                         id_name          ra  ra_err       dec  dec_err  \
# 0   b'SDSS J083701.85-011324.4'  129.257736     NaN -1.223454      NaN
# 2   b'SDSS J083703.99-011413.0'  129.266647     NaN -1.236966      NaN
# 3   b'SDSS J083704.38-010758.4'  129.268265     NaN -1.132909      NaN
# 4   b'SDSS J083706.68-010802.3'  129.277863     NaN -1.133993      NaN
# 16  b'SDSS J083725.46-011056.3'  129.356094     NaN -1.182314      NaN
# 18  b'SDSS J083709.21-010925.3'  129.288376     NaN -1.157034      NaN
# 19  b'SDSS J083709.51-011310.4'  129.289627     NaN -1.219575      NaN
# 20  b'SDSS J083709.48-011228.4'  129.289536     NaN -1.207892      NaN
# 22  b'SDSS J083711.82-011536.7'  129.299286     NaN -1.260201      NaN
# 26  b'SDSS J083713.44-011215.6'  129.306046     NaN -1.204359      NaN
# 29  b'SDSS J083714.40-011024.8'  129.309998     NaN -1.173565      NaN
# 30  b'SDSS J083716.10-011542.2'  129.317108     NaN -1.261740      NaN
# 33  b'SDSS J083717.56-011521.5'  129.323196     NaN -1.255994      NaN
# 34  b'SDSS J083718.61-011105.9'  129.327545     NaN -1.184980      NaN
# 36  b'SDSS J083719.43-011336.7'  129.330963     NaN -1.226885      NaN
# 37  b'SDSS J083719.49-011255.5'  129.331238     NaN -1.215417      NaN
# 40  b'SDSS J083722.45-011000.2'  129.343567     NaN -1.166741      NaN
# 41  b'SDSS J083724.63-011240.3'  129.352646     NaN -1.211205      NaN
#
#       SDSS_up    SDSS_gp    SDSS_rp    SDSS_ip    SDSS_zp  ...  SDSS_gp_err  \
# 0   18.750443  17.614172  17.172199  17.019323  16.968107  ...     0.017703
# 2   17.288340  15.899622  15.388712  15.211289  15.158859  ...     0.017366
# 3   18.964325  16.818647  15.929386  15.634903  15.505053  ...     0.017473
# 4   18.311979  17.136492  16.586887  16.392420  16.311769  ...     0.017541
# 16  18.824638  17.734657  17.314240  17.173977  17.113718  ...     0.014418
# 18  18.533169  17.633896  17.297276  17.190144  17.159523  ...     0.014429
# 19  16.469753  15.204407  14.833443  14.718861  14.709348  ...     0.013958
# 20  18.760679  17.675598  17.315100  17.187006  17.140427  ...     0.014457
# 22  17.158810  15.899879  15.537637  15.393700  15.366141  ...     0.014008
# 26  16.006865  14.926799  14.647436  14.569443  14.582277  ...     0.014740
# 29  17.016672  15.949787  15.595329  15.491165  15.470160  ...     0.014007
# 30  18.413290  17.307354  16.969021  16.854843  16.856936  ...     0.014288
# 33  16.769598  15.499763  15.050758  14.885879  14.821561  ...     0.013973
# 34  16.818882  14.673591  13.806436  13.503417  13.350910  ...     0.013935
# 36  18.930740  17.286070  16.690992  16.498898  16.396858  ...     0.014285
# 37  18.380795  16.960793  16.483416  16.353075  16.294374  ...     0.014153
# 40  18.986826  16.498362  15.324529  14.796546  14.479912  ...     0.014073
# 41  18.977945  17.321718  16.728939  16.535561  16.438494  ...     0.014242
#
#     SDSS_rp_err  SDSS_ip_err  SDSS_zp_err  UKIDSS_LAS_Y_err     ipix  bucket  \
# 0      0.009984     0.016463     0.020989          0.009085  1397653     909
# 2      0.009543     0.016135     0.019059          0.002993  1397653     909
# 3      0.009600     0.016161     0.019184          0.003562  1397655     909
# 4      0.009723     0.016263     0.019740          0.005840  1397653     909
# 16     0.010551     0.016961     0.019221          0.010463  1397653     909
# 18     0.010520     0.016953     0.019483          0.010486  1397653     909
# 19     0.010019     0.016558     0.016632          0.002416  1397653     909
# 20     0.010555     0.016970     0.019451          0.010536  1397653     909
# 22     0.010072     0.016596     0.016837          0.003417  1397567     909
# 26     0.016064     0.025415     0.028362          0.002289  1397653     909
# 29     0.010075     0.016600     0.016869          0.003657  1397653     909
# 30     0.010395     0.016847     0.018641          0.008402  1397567     909
# 33     0.010030     0.016567     0.016645          0.002540  1397567     909
# 34     0.009985     0.016532     0.016479          0.001177  1397653     909
# 36     0.010343     0.016805     0.017760          0.006198  1397653     909
# 37     0.010227     0.016711     0.017549          0.005960  1397653     909
# 40     0.010050     0.016562     0.016587          0.001971  1397696     909
# 41     0.010297     0.016751     0.017754          0.006455  1397653     909
#
#           x_pix        y_pix  edge_dist_pix
# 0   1293.182278  1170.926156     753.817722
# 2   1200.251960  1313.920844     733.079156
# 3   1176.169752   217.378583     217.378583
# 4   1075.177930   229.500410     229.500410
# 16   254.017412   744.360629     254.017412
# 18   965.853684   473.111723     473.111723
# 19   956.967781  1132.257710     914.742290
# 20   957.036776  1009.149249     957.036776
# 22   858.003674  1560.952848     486.047152
# 26   782.917764   973.084385     782.917764
# 29   739.086410   648.874749     648.874749
# 30   670.293016  1578.380916     468.619084
# 33   605.703195  1518.267796     528.732204
# 34   555.035279   770.410477     555.035279
# 36   521.929837  1212.159386     521.929837
# 37   518.258668  1091.360251     518.258668
# 40   384.947899   579.374321     384.947899
# 41   292.282686  1048.488141     292.282686
#
# [18 rows x 22 columns]

# %%
standard_star.plot_standard_stars_on_fits(
    fits_path="Master_SDSS J083701.85-011324.4_SDSS_g'.fits",
    df_stars= standard_star_table,
    hdu_index=0,
    marker_size=80.0,
    marker_edgecolor="red",
    marker_facecolor="none",
    marker_linewidth=1.5,
    cmap="gray",
    stretch="sqrt",
    percent=99.0,
    figsize=(8, 8),
    title="Standard Stars in FOV",
)
# Out:
# (<Figure size 800x800 with 1 Axes>,
#  <WCSAxes: title={'center': 'Standard Stars in FOV'}>)
